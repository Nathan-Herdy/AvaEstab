# %%
import pandas as pd
import numpy as np

# %%
base = pd.read_csv(filepath_or_buffer='BDSCLEANED.txt ', sep = '\t')

# %%
base.columns[120:]
# Out:
# Index(['COParea - Open - Foam', 'COPvelo - Open - Foam',
#        'COPmfreq - Open - Foam', 'x_mean_value_detrended_cop - Open - Foam',
#        'x_variance_cop - Open - Foam', 'x_skewness_cop - Open - Foam',
#        'x_rms_cop - Open - Foam', 'x_peaky_to_peaky_cop - Open - Foam',
#        'x_crest_factor_cop - Open - Foam', 'x_mean_speed_cop - Open - Foam',
#        'x_Mean_Resultant_Speed_cop - Open - Foam',
#        'x_fpcntile50_cop - Open - Foam', 'x_fpcntile95_cop - Open - Foam',
#        'x_Peaky_Frequency_cop - Open - Foam',
#        'x_Mean_Frequency_cop - Open - Foam', 'x_Total_power_cop - Open - Foam',
#        'y_mean_value_detrended_cop - Open - Foam',
#        'y_variance_cop - Open - Foam', 'y_skewness_cop - Open - Foam',
#        'y_rms_cop - Open - Foam', 'y_peaky_to_peaky_cop - Open - Foam',
#        'y_crest_factor_cop - Open - Foam', 'y_mean_speed_cop - Open - Foam',
#        'y_Mean_Resultant_Speed_cop - Open - Foam',
# ...

# %%
x = base.drop(['Unnamed: 0', 'Subject', 'AgeGroup', 
        'BMI', 'FootLen', 'Nationality', 'SkinColor', 'Ystudy',
       'Footwear', 'Illness', 'Illness2', 'Nmedication', 'Medication',
       'Ortho-Prosthesis', 'Ortho-Prosthesis2', 'Disability', 'Disability2',
       'Falls12m', 'FES_1', 'FES_2', 'FES_3', 'FES_4', 'FES_5', 'FES_6',
       'FES_7', 'FES_T', 'FES_S', 'IPAQ_1a', 'IPAQ_1b', 'IPAQ_2a', 'IPAQ_2b',
       'IPAQ_3a', 'IPAQ_3b', 'IPAQ_4a', 'IPAQ_4b', 'IPAQ_S', 'TMT_timeA',
       'TMT_errorsA', 'TMT_timeB', 'TMT_errorsB', 'Best_1', 'Best_2',
       'Best_3l', 'Best_3r', 'Best_4', 'Best_5', 'Best_6l', 'Best_6r',
       'Best_7', 'Best_8', 'Best_9', 'Best_10', 'Best_11', 'Best_12',
       'Best_13', 'Best_14','Best_T','APA', 'RPC', 'SO', 'DG'],axis =1 )

# %%
x
# Out:
#            Age  Gender  Height  Weight  COParea - Open - Firm  \
# 0    33.000000       0   157.5   54.20               0.827615
# 1    27.583333       0   154.0   44.00               0.632228
# 2    36.916667       1   161.7   63.40               3.224678
# 3    61.750000       1   164.0   68.35               3.815930
# 4    18.333333       0   162.0   56.45               3.129373
# ..         ...     ...     ...     ...                    ...
# 153  24.750000       0   153.5   62.05               0.912748
# 154  23.583333       0   161.5   56.55               1.531402
# 155  25.333333       0   167.7   60.55               3.281855
# 156  24.083333       1   183.5   63.20               1.677234
# 157  25.416667       1   172.0   74.60               2.148530
#
#      COPvelo - Open - Firm  COPmfreq - Open - Firm  \
# 0                 0.656039                0.235659
# 1                 0.543046                0.224833
# 2                 1.062107                0.238608
# ...

# %%
x.to_csv('BDSX.txt', sep='\t')

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.StandardScaler().fit(x)

# %%
X_scaled = scaler.transform(x)

# %%
X_scaled = pd.DataFrame(X_scaled)

# %%
X_scaled
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.635983 -0.621261 -0.515707 -0.984572 -0.810008 -0.893661 -0.331704
# 1   -0.872840 -0.621261 -0.879232 -2.243237 -0.896896 -1.192832 -0.439648
# 2   -0.464718  1.609630 -0.079476  0.150695  0.255957  0.181494 -0.302302
# 3    0.621177  1.609630  0.159412  0.761517  0.518884  0.490253 -0.043515
# 4   -1.277317 -0.621261 -0.048317 -0.706925  0.213575 -0.437845 -1.477571
# ..        ...       ...       ...       ...       ...       ...       ...
# 153 -0.996734 -0.621261 -0.931165 -0.015893 -0.772150 -1.082258 -0.629549
# 154 -1.047749 -0.621261 -0.100249 -0.694585 -0.497036 -0.609091  0.450604
# 155 -0.971226 -0.621261  0.543711 -0.200991  0.281383 -0.477424 -1.054011
# 156 -1.025885  1.609630  2.184769  0.126015 -0.432186 -0.828725 -0.997333
# 157 -0.967582  1.609630  0.990328  1.532758 -0.222602 -0.322276 -0.708963
#
#           7         8         9    ...       111       112       113  \
# ...

# %%
X_scaled.to_csv('BDSX_SCALED.txt',sep='\t')
